# %% [markdown]
# <a href="https://colab.research.google.com/github/sudhakavyaa4919-dot/AIML-assignment/blob/main/linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

df = pd.read_csv("homeprices (2).csv")

plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area, df.price, color="red", marker="+")

# create linear regression object and fit the data
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)

# draw regression line
plt.plot(df.area, reg.predict(df[['area']]))

# prediction
reg.predict([[65471]])

# slope (m)
reg.coef_

# intercept (b)
reg.intercept_
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(180616.43835616432)
