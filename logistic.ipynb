# %% [markdown]
# <a href="https://colab.research.google.com/github/sudhakavyaa4919-dot/AIML-assignment/blob/main/logistic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# 2. Read the dataset
df = pd.read_csv("insurance_data (2).csv")

# 3. Display first 5 rows
print(df.head())

# 4. Scatter plot to visualize data
plt.scatter(df.age, df.bought_insurance, marker='+', color='red')
plt.xlabel("Age")
plt.ylabel("Bought Insurance")
plt.title("Age vs Bought Insurance")
plt.show()

# 5. Split data into input (X) and output (y)
X = df[['age']]              # Independent variable
y = df['bought_insurance']   # Dependent variable

# 6. Train-test split (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.8, random_state=42
)

# 7. Create Logistic Regression model
model = LogisticRegression()

# 8. Train the model
model.fit(X_train, y_train)

# 9. Predict using test data
y_predicted = model.predict(X_test)

# 10. Print predictions
print("Predicted values:", y_predicted.tolist())
print("Actual values   :", y_test.tolist())

# 11. Predict probabilities
probabilities = model.predict_proba(X_test)
print("\nPrediction Probabilities:")
print(probabilities)

# 12. Check model accuracy
accuracy = model.score(X_test, y_test)
print("\nModel Accuracy:", accuracy)

# 13. Predict for a new age value
age = [[35]]
prediction = model.predict(age)
prob = model.predict_proba(age)

print("\nPrediction for age 35:")
print("Will buy insurance?" , prediction[0])
print("Probability:", prob)
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1
# Predicted values: [1, 0, 1, 0, 0, 0]
# Actual values   : [1, 0, 1, 0, 0, 0]
#
# Prediction Probabilities:
# [[0.05428672 0.94571328]
#  [0.7055532  0.2944468 ]
#  [0.06039333 0.93960667]
#  [0.77084966 0.22915034]
#  [0.84096469 0.15903531]
#  [0.72848723 0.27151277]]
#
# Model Accuracy: 1.0
#
# Prediction for age 35:
# Will buy insurance? 0
# Probability: [[0.54870045 0.45129955]]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
